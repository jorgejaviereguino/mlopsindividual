# %% [markdown]
# ## MLOPs Individual Assignment

# %% [markdown]
# Prof. Juan Iglesias Cavada
#
# MBD Oct 2019
#
# June 2020
#
# #### Jorge Javier Eguino

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import re
import time
import math
import requests
from requests.auth import HTTPBasicAuth
import urllib.request as urllib2
import os.path
import time
import matplotlib.pylab as plt
import seaborn as sns
# %matplotlib inline
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, SimpleImputer
from sklearn.decomposition import PCA, KernelPCA
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor, RadiusNeighborsRegressor,RadiusNeighborsClassifier
from sklearn.feature_selection import chi2, GenericUnivariateSelect, SelectKBest, SelectPercentile, RFE
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor, GradientBoostingRegressor, GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import (accuracy_score, f1_score, confusion_matrix,
                             classification_report, precision_score,
                             recall_score, roc_curve, auc, roc_auc_score, make_scorer)
from sklearn.svm import SVC, SVR
from sklearn.decomposition import PCA, KernelPCA
from sklearn.model_selection import cross_validate, cross_val_predict, cross_validate, cross_val_score, GridSearchCV, ParameterGrid
from xgboost import XGBRegressor, XGBClassifier

# %%
df = pd.read_csv("swedish_crime_rate.csv")

# %%
df.shape
# Out:
# (66, 21)

# %%
df.head(40)
# Out:
#     Year  crimes.total  crimes.penal.code  crimes.person  murder  assault  \
# 0   1950          2784               2306            120       1      105
# 1   1951          3284               2754            125       1      109
# 2   1952          3160               2608            119       1      104
# 3   1953          2909               2689            119       1      105
# 4   1954          3028               2791            126       1      107
# 5   1955          3357               3101            135       1      118
# 6   1956          3488               3215            133       1      116
# 7   1957          3774               3520            133       1      116
# 8   1958          4064               3791            127       1      113
# 9   1959          4033               3733            125       1      110
# 10  1960          3982               3694            131       1      116
# 11  1961          4108               3747            131       1      116
# ...
